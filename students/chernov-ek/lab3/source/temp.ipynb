# %%
import kagglehub
from pathlib import Path
import shutil

import numpy as np
from sklearn.metrics import classification_report

from svm_model import CustomSVM
from utils import get_samples

# %%
X_train, X_test, y_train, y_test = get_samples()
# Out:
# Downloading to /home/redduck/.cache/kagglehub/datasets/romaneyvazov/32-dsdds/1.archive...
# 100%|██████████| 19.3k/19.3k [00:00<00:00, 9.49MB/s]
# Extracting files...

# %%
model = CustomSVM(
    kernel_name="linear",
    C=1
)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.71       229
#            1       0.00      0.00      0.00       183
#
#     accuracy                           0.56       412
#    macro avg       0.28      0.50      0.36       412
# weighted avg       0.31      0.56      0.40       412
# /home/redduck/VSProjects/fall-2025/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/redduck/VSProjects/fall-2025/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/redduck/VSProjects/fall-2025/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
model = CustomSVM(
    kernel_name="poly",
    C=1,
    degree=3
)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.71       229
#            1       0.00      0.00      0.00       183
#
#     accuracy                           0.56       412
#    macro avg       0.28      0.50      0.36       412
# weighted avg       0.31      0.56      0.40       412
# /home/redduck/VSProjects/fall-2025/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/redduck/VSProjects/fall-2025/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/redduck/VSProjects/fall-2025/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
model = CustomSVM(
    kernel_name="rbf",
    C=1,
    gamma=0.5
)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
